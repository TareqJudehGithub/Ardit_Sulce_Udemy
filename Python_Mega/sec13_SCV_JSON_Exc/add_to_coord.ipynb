# %%
import pandas

# %%
import geopy
from geopy.geocoders import ArcGIS
arc = ArcGIS()

# %%
data = pandas.read_csv("data.txt")
data
# Out:
#    0     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 0  1   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 1  2      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 2  3     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 3  4  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 4  5  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
data.columns = ["ID", "Addres", "State", "Zip Code", "Country", "Customer", "Employee"]
data.columns
# Out:
# Index(['ID', 'Addres', 'State', 'Zip Code', 'Country', 'Customer', 'Employee'], dtype='object')

# %%
data
# Out:
#    ID           Addres          State          Zip Code Country     Customer  \
# 0   1   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 1   2      332 Hill St  San Francisco  California 94114     USA  Super River
# 2   3     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 3   4  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 4   5  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employee
# 0        15
# 1        25
# 2        10
# 3        12
# 4        20

# %%
# display geographical location (longitude and latitude): 
my_address = arc.geocode("182-21 150th Avenue, Springfield Gardns, NY 11413")

# longitude
long = my_address.longitude

# latitude
lati = my_address.latitude
long, lati
# Out:
# (-73.76539577595815, 40.65728884807243)

# %%
sd = pandas.read_csv("supermarkets_csv.csv")
sd
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# update the Address columns data to have the full address to be used in geopy library
sd["Address"] = f'{sd["City"]}'
sd
# Out:
#    ID                                            Address           City  \
# 0   1  0    San Francisco\n1    San Francisco\n2    S...  San Francisco
# 1   2  0    San Francisco\n1    San Francisco\n2    S...  San Francisco
# 2   3  0    San Francisco\n1    San Francisco\n2    S...  San Francisco
# 3   4  0    San Francisco\n1    San Francisco\n2    S...  San Francisco
# 4   5  0    San Francisco\n1    San Francisco\n2    S...  San Francisco
# 5   6  0    San Francisco\n1    San Francisco\n2    S...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
sd["Coords"] = sd["Address"].apply(arc.geocode)
sd
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                             Coords
# 0          8  (Travessa da Santa 21, 4740-451, Santa, Espose...
# 1         15  (Dolores, Eastern Samar, Eastern Visayas, (12....
# 2         25  (Hill Street, Connaught, (53.88333000000006, -...
# 3         10                                               None
# 4         12  (Sánchez, (19.23073000000005, -69.612949999999...
# ...

# %%
# latitude for the first address coords
sd.Coords[0].latitude
# Out:
# 41.60958032363286
